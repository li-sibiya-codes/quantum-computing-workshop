# %%
# !pip install qiskit
# !pip install pylatexenc
# Out:
# Collecting qiskit
#   Downloading qiskit-2.4.2-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (14 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.21 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.8.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.15.0)
# Downloading qiskit-2.4.2-cp310-abi3-manylinux_2_28_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 22.1 MB/s eta 0:00:00
# Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 95.6 MB/s eta 0:00:00
# Downloading stevedore-5.8.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: stevedore, rustworkx, qiskit
# Successfully installed qiskit-2.4.2 rustworkx-0.18.0 stevedore-5.8.0
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=b25f1947f462798dee30cf67acedaec8a85be331b90ad30bda5d193eebaaf0ed
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10

# %%
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
import matplotlib.pyplot as mpl
from qiskit.quantum_info import Statevector

# %%
q = QuantumRegister(4)
c = ClassicalRegister(4)
qc = QuantumCircuit(q,c)

qc.x(q[0])
qc.x(q[3])
qc.h(q[1])
qc.cx(q[1], q[2])
qc.cx(q[1], q[3])

qc.draw('mpl')

# %%
state=Statevector(qc)
state.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{2} |0111\rangle+\frac{\sqrt{2}}{2} |1001\rangle$$

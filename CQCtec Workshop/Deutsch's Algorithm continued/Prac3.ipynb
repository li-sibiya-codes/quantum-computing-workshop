# %%
# !pip install qiskit
# !pip install qiskit_aer
# !pip install pylatexenc
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 90.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 57.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=a57bf8c3586ad9d7c6c108a8dd3ee7c72629111fc762fcc75be87feba05a4bb7
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# ...

# %%
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit_aer import AerSimulator
import matplotlib.pyplot as mpl

# %%
q = QuantumRegister(3)
c = ClassicalRegister(2)
qc = QuantumCircuit(q,c)

qc.h(q[0])
qc.h(q[1])
qc.x(q[2])
qc.h(q[2])
qc.barrier()
qc.ccx(q[0], q[1], q[2])
qc.x(q[2])
qc.barrier()
qc.h(q[0])
qc.h(q[1])
qc.measure(q[0],c[0])
qc.measure(q[1],c[1])
qc.draw('mpl')

# %%
simulator = AerSimulator()
result=simulator.run(qc).result()
counts = result.get_counts()
print(counts)
# Out:
# {'11': 250, '10': 262, '00': 225, '01': 287}

# %% [markdown]
# {'01': 273, '11': 228, '00': 247, '10': 276}

# %%
qA = QuantumRegister(3)
cA = ClassicalRegister(2)
qcA = QuantumCircuit(qA,cA)

qcA.h(qA[0])
qcA.h(qA[1])
qcA.x(qA[2])
qcA.h(qA[2])
qcA.barrier()
qcA.cx(qA[0], qA[2])
qcA.cx(qA[1], qA[2])
qcA.ccx(qA[0], qA[1], qA[2])
qcA.barrier()
qcA.h(qA[0])
qcA.h(qA[1])
qcA.measure(qA[0],cA[0])
qcA.measure(qA[1],cA[1])

qcA.draw('mpl')

# %%
simulator = AerSimulator()
result=simulator.run(qcA).result()
counts = result.get_counts()
print(counts)
# Out:
# {'01': 273, '11': 228, '00': 247, '10': 276}

# %%
qB = QuantumRegister(3)
cB = ClassicalRegister(2)
qcB = QuantumCircuit(qB,cB)

qcB.h(qB[0])
qcB.h(qB[1])
qcB.x(qB[2])
qcB.h(qB[2])
qcB.barrier()
qcB.ccx(qB[0], qB[1], qB[2])
qcB.cx(qB[0], qB[2])
qcB.cx(qB[1], qB[2])
qcB.x(qB[0])
qcB.x(qB[1])
qcB.ccx(qB[0], qB[1], qB[2])
qcB.x(qB[0])
qcB.x(qB[1])
qcB.barrier()
qcB.h(qB[0])
qcB.h(qB[1])
qcB.measure(qB[0],cB[0])
qcB.measure(qB[1],cB[1])

qcB.draw('mpl')

# %%
simulator = AerSimulator()
result=simulator.run(qcB).result()
counts = result.get_counts()
print(counts)
# Out:
# {'00': 1024}
